# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.karate_club_graph()

# %%
plt.figure(figsize=(25,10))
ax = plt.gca()
ax.set_title('Zacharys Karate Club - Network Circular Plot')
nx.draw_networkx(G, ax=ax, with_labels=True,node_color="mediumspringgreen", node_shape="^", node_size=800)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\networkx\utils\decorators.py:396, in random_state.<locals>._random_state(func, *args, **kwargs)
#     395 try:
# --> 396     random_state_arg = args[random_state_index]
#     397 except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In [9], line 4
#       2 ax = plt.gca()
#       3 ax.set_title('Zacharys Karate Club - Network Circular Plot')
# ----> 4 nx.draw_networkx(G, ax=ax, with_labels=True,node_color="mediumspringgreen", node_shape="^", node_size=800)
#
# File ~\anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:333, in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     330 label_kwds = {k: v for k, v in kwds.items() if k in valid_label_kwds}
#     332 if pos is None:
# --> 333     pos = nx.drawing.spring_layout(G)  # default to spring layout
#     335 draw_networkx_nodes(G, pos, **node_kwds)
#     336 draw_networkx_edges(G, pos, arrows=arrows, **edge_kwds)
#
# File ~\anaconda3\lib\site-packages\decorator.py:231, in decorate.<locals>.fun(*args, **kw)
#     229 if not kwsyntax:
#     230     args, kw = fix(args, kw, sig)
# --> 231 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\lib\site-packages\networkx\utils\decorators.py:400, in random_state.<locals>._random_state(func, *args, **kwargs)
#     398     raise nx.NetworkXError("random_state_index must be an integer") from e
#     399 except IndexError as e:
# --> 400     raise nx.NetworkXError("random_state_index is incorrect") from e
#     402 # Create a numpy.random.RandomState instance
#     403 random_state = create_random_state(random_state_arg)
#
# NetworkXError: random_state_index is incorrect
